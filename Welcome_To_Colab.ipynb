# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha0118/-Cross-Validation-Techniques-using-an-SVM-Classifier-/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
datagen=ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    rescale=None,
    fill_mode='reflect'
)

# %%
img = load_img('/content/dog-puppy-on-garden-royalty-free-image-1586966191.avif')

# %%
img.show()

# %%
import os

x=img_to_array(img)
x=x.reshape((1,)+x.shape)

# Create a directory to save the augmented images
save_dir = '/content/augmented_images'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

i=0
for batch in datagen.flow(x,batch_size=1,
                          save_to_dir=save_dir,
                          save_prefix='dog',save_format='jpeg'):
  i+=1
  if i>30:
    break
